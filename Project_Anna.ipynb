# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

# %%
#importing web data
df_curr = pd.read_html('https://www.extratime.com/competition/2123/202/2022-world-cup/')
df_curr
# Out:
# [   Unnamed: 0         Team       Pd  W  D  L  GF  GA  GD  Pts  Form  \
#  0           1  Netherlands  N'lands  3  2  1   0   5   1    4     7
#  1           2      Senegal  Senegal  3  2  0   1   5   4    1     6
#  2           3      Ecuador  Ecuador  3  1  1   1   4   3    1     4
#  3           4        Qatar    Qatar  3  0  0   3   1   7   -6     0
#
#       Unnamed: 11
#  0  W  D  W  W  D
#  1     L  W  W  L
#  2        W  D  L
#  3        L  L  L  ,
#     Unnamed: 0     Team       Pd  W  D  L  GF  GA  GD  Pts  Form    Unnamed: 11
#  0           1  England  England  3  2  1   0   9   2    7     7  W  D  W  W  L
#  1           2      USA      USA  3  1  2   0   2   1    1     5     D  D  W  L
#  2           3     Iran     Iran  3  1  0   2   4   7   -3     3        L  W  L
#  3           4    Wales    Wales  3  0  1   2   1   6   -5     1        D  L  L,
#     Unnamed: 0          Team            Pd  W  D  L  GF  GA  GD  Pts  Form  \
# ...

# %%
#returning the type of data
type(df_curr)
# Out:
# list

# %%
#returning the number of items in list
len(df_curr)
# Out:
# 9

# %%
#converting each item of a list to a DataFrame - it needs to visualize the data in the next step
df_1group = pd.DataFrame(df_curr[0])
df_1group
# Out:
#    Unnamed: 0         Team       Pd  W  D  L  GF  GA  GD  Pts  Form  \
# 0           1  Netherlands  N'lands  3  2  1   0   5   1    4     7
# 1           2      Senegal  Senegal  3  2  0   1   5   4    1     6
# 2           3      Ecuador  Ecuador  3  1  1   1   4   3    1     4
# 3           4        Qatar    Qatar  3  0  0   3   1   7   -6     0
#
#      Unnamed: 11
# 0  W  D  W  W  D
# 1     L  W  W  L
# 2        W  D  L
# 3        L  L  L

# %%
df_2group = pd.DataFrame(df_curr[1])
df_2group
# Out:
#    Unnamed: 0     Team       Pd  W  D  L  GF  GA  GD  Pts  Form    Unnamed: 11
# 0           1  England  England  3  2  1   0   9   2    7     7  W  D  W  W  L
# 1           2      USA      USA  3  1  2   0   2   1    1     5     D  D  W  L
# 2           3     Iran     Iran  3  1  0   2   4   7   -3     3        L  W  L
# 3           4    Wales    Wales  3  0  1   2   1   6   -5     1        D  L  L

# %%
df_3group = pd.DataFrame(df_curr[2])
df_3group
# Out:
#    Unnamed: 0          Team            Pd  W  D  L  GF  GA  GD  Pts  Form  \
# 0           1     Argentina     Argentina  3  2  0   1   5   2    3     6
# 1           2        Poland        Poland  3  1  1   1   2   2    0     4
# 2           3        Mexico        Mexico  3  1  1   1   2   3   -1     4
# 3           4  Saudi Arabia  Saudi Arabia  3  1  0   2   3   5   -2     3
#
#      Unnamed: 11
# 0  W  W  D  W  D
# 1     D  W  L  L
# 2        D  L  W
# 3        W  L  L

# %%
df_4group = pd.DataFrame(df_curr[3])
df_4group
# Out:
#    Unnamed: 0       Team         Pd  W  D  L  GF  GA  GD  Pts  Form  \
# 0           1     France     France  3  2  0   1   6   3    3     6
# 1           2  Australia  Australia  3  2  0   1   3   4   -1     6
# 2           3    Tunisia    Tunisia  3  1  1   1   1   1    0     4
# 3           4    Denmark    Denmark  3  0  1   2   1   3   -2     1
#
#      Unnamed: 11
# 0  L  W  W  W  D
# 1     L  W  W  L
# 2        D  L  W
# 3        D  L  L

# %%
df_5group = pd.DataFrame(df_curr[4])
df_5group
# Out:
#    Unnamed: 0        Team          Pd  W  D  L  GF  GA  GD  Pts  Form  \
# 0           1       Japan       Japan  3  2  0   1   4   3    1     6
# 1           2       Spain       Spain  3  1  1   1   9   3    6     4
# 2           3     Germany     Germany  3  1  1   1   6   5    1     4
# 3           4  Costa Rica  Costa Rica  3  1  0   2   3  11   -8     3
#
#   Unnamed: 11
# 0  W  L  W  D
# 1  W  D  L  D
# 2     L  D  W
# 3     L  W  L

# %%
df_6group = pd.DataFrame(df_curr[5])
df_6group
# Out:
#    Unnamed: 0     Team       Pd  W  D  L  GF  GA  GD  Pts  Form    Unnamed: 11
# 0           1  Morocco  Morocco  3  2  1   0   4   1    3     7  W  D  W  L  L
# 1           2  Croatia  Croatia  3  1  2   0   4   1    3     5  D  D  D  L  W
# 2           3  Belgium  Belgium  3  1  1   1   1   2   -1     4        W  L  D
# 3           4   Canada   Canada  3  0  0   3   2   7   -5     0        L  L  L

# %%
df_7group = pd.DataFrame(df_curr[6])
df_7group
# Out:
#    Unnamed: 0         Team      Pd  W  D  L  GF  GA  GD  Pts  Form  \
# 0           1       Brazil  Brazil  3  2  0   1   3   1    2     6
# 1           2  Switzerland   Swiss  3  2  0   1   4   3    1     6
# 2           3     Cameroon     CMR  3  1  1   1   4   4    0     4
# 3           4       Serbia  Serbia  3  0  1   2   5   8   -3     1
#
#      Unnamed: 11
# 0  W  W  L  W  D
# 1     W  L  W  L
# 2        L  D  W
# 3        L  D  L

# %%
df_8group = pd.DataFrame(df_curr[7])
df_8group
# Out:
#    Unnamed: 0         Team           Pd  W  D  L  GF  GA  GD  Pts  Form  \
# 0           1     Portugal     Portugal  3  2  0   1   6   4    2     6
# 1           2  South Korea  South Korea  3  1  1   1   4   4    0     4
# 2           3      Uruguay      Uruguay  3  1  1   1   2   2    0     4
# 3           4        Ghana        Ghana  3  1  0   2   5   7   -2     3
#
#      Unnamed: 11
# 0  W  W  L  W  L
# 1     D  L  W  L
# 2        D  L  W
# 3        L  W  L

# %%
df_9group = pd.DataFrame(df_curr[8])
df_9group
# Out:
# Empty DataFrame
# Columns: [Player, Total Goals, Penos]
# Index: []

# %%
#merging all DataFrames into one
df_all = pd.DataFrame()
for f in df_curr:
  df_all = pd.concat([df_all,f])

#2 option:
#all_groups = pd.concat([df_1group,df_2group,df_3group,df_4group,df_5group,df_6group,df_7group,df_8group])
#all_groups

df_all
# Out:
#    Unnamed: 0          Team            Pd    W    D    L   GF   GA    GD  Pts  \
# 0         1.0   Netherlands       N'lands  3.0  2.0  1.0  0.0  5.0   1.0  4.0
# 1         2.0       Senegal       Senegal  3.0  2.0  0.0  1.0  5.0   4.0  1.0
# 2         3.0       Ecuador       Ecuador  3.0  1.0  1.0  1.0  4.0   3.0  1.0
# 3         4.0         Qatar         Qatar  3.0  0.0  0.0  3.0  1.0   7.0 -6.0
# 0         1.0       England       England  3.0  2.0  1.0  0.0  9.0   2.0  7.0
# 1         2.0           USA           USA  3.0  1.0  2.0  0.0  2.0   1.0  1.0
# 2         3.0          Iran          Iran  3.0  1.0  0.0  2.0  4.0   7.0 -3.0
# 3         4.0         Wales         Wales  3.0  0.0  1.0  2.0  1.0   6.0 -5.0
# 0         1.0     Argentina     Argentina  3.0  2.0  0.0  1.0  5.0   2.0  3.0
# 1         2.0        Poland        Poland  3.0  1.0  1.0  1.0  2.0   2.0  0.0
# 2         3.0        Mexico        Mexico  3.0  1.0  1.0  1.0  2.0   3.0 -1.0
# ...

# %%
#renaming columns because there was a shift in the names during importing from webpage and consolidation of changes
df_all.rename(columns={
    'Unnamed: 0':'Place in Group',
    'Pd':'Country',
    'W':'Played',
    'D':'Won',
    'L':'Draw',
    'GF':'Loss',
    'GA':'Goals For',
    'GD':'Goals Against',
    'Pts':'Goal Difference',
    'Form':'Points',
    'Unnamed: 11':'Form'
}, inplace=True)
df_all
# Out:
#    Place in Group          Team       Country  Played  Won  Draw  Loss  \
# 0             1.0   Netherlands       N'lands     3.0  2.0   1.0   0.0
# 1             2.0       Senegal       Senegal     3.0  2.0   0.0   1.0
# 2             3.0       Ecuador       Ecuador     3.0  1.0   1.0   1.0
# 3             4.0         Qatar         Qatar     3.0  0.0   0.0   3.0
# 0             1.0       England       England     3.0  2.0   1.0   0.0
# 1             2.0           USA           USA     3.0  1.0   2.0   0.0
# 2             3.0          Iran          Iran     3.0  1.0   0.0   2.0
# 3             4.0         Wales         Wales     3.0  0.0   1.0   2.0
# 0             1.0     Argentina     Argentina     3.0  2.0   0.0   1.0
# 1             2.0        Poland        Poland     3.0  1.0   1.0   1.0
# 2             3.0        Mexico        Mexico     3.0  1.0   1.0   1.0
# 3             4.0  Saudi Arabia  Saudi Arabia     3.0  1.0   0.0   2.0
# ...

# %%
#removing columns without data
df_all = df_all.drop(columns = ['Country','Player','Total Goals','Penos'], axis=1)
df_all
# Out:
#    Place in Group          Team  Played  Won  Draw  Loss  Goals For  \
# 0             1.0   Netherlands     3.0  2.0   1.0   0.0        5.0
# 1             2.0       Senegal     3.0  2.0   0.0   1.0        5.0
# 2             3.0       Ecuador     3.0  1.0   1.0   1.0        4.0
# 3             4.0         Qatar     3.0  0.0   0.0   3.0        1.0
# 0             1.0       England     3.0  2.0   1.0   0.0        9.0
# 1             2.0           USA     3.0  1.0   2.0   0.0        2.0
# 2             3.0          Iran     3.0  1.0   0.0   2.0        4.0
# 3             4.0         Wales     3.0  0.0   1.0   2.0        1.0
# 0             1.0     Argentina     3.0  2.0   0.0   1.0        5.0
# 1             2.0        Poland     3.0  1.0   1.0   1.0        2.0
# 2             3.0        Mexico     3.0  1.0   1.0   1.0        2.0
# 3             4.0  Saudi Arabia     3.0  1.0   0.0   2.0        3.0
# 0             1.0        France     3.0  2.0   0.0   1.0        6.0
# ...

# %%
#reindexing (to do it in place without saving the old index)
df_all.reset_index(inplace=True,drop=True)
df_all
# Out:
#     Place in Group          Team  Played  Won  Draw  Loss  Goals For  \
# 0              1.0   Netherlands     3.0  2.0   1.0   0.0        5.0
# 1              2.0       Senegal     3.0  2.0   0.0   1.0        5.0
# 2              3.0       Ecuador     3.0  1.0   1.0   1.0        4.0
# 3              4.0         Qatar     3.0  0.0   0.0   3.0        1.0
# 4              1.0       England     3.0  2.0   1.0   0.0        9.0
# 5              2.0           USA     3.0  1.0   2.0   0.0        2.0
# 6              3.0          Iran     3.0  1.0   0.0   2.0        4.0
# 7              4.0         Wales     3.0  0.0   1.0   2.0        1.0
# 8              1.0     Argentina     3.0  2.0   0.0   1.0        5.0
# 9              2.0        Poland     3.0  1.0   1.0   1.0        2.0
# 10             3.0        Mexico     3.0  1.0   1.0   1.0        2.0
# 11             4.0  Saudi Arabia     3.0  1.0   0.0   2.0        3.0
# 12             1.0        France     3.0  2.0   0.0   1.0        6.0
# ...

# %%
#saving data and changes to a file
df_all.to_csv('Fifa_2022.csv')

# %%
#selecting by columns
df_all[['Team','Points']]
# Out:
#             Team  Points
# 0    Netherlands     7.0
# 1        Senegal     6.0
# 2        Ecuador     4.0
# 3          Qatar     0.0
# 4        England     7.0
# 5            USA     5.0
# 6           Iran     3.0
# 7          Wales     1.0
# 8      Argentina     6.0
# 9         Poland     4.0
# 10        Mexico     4.0
# 11  Saudi Arabia     3.0
# 12        France     6.0
# 13     Australia     6.0
# 14       Tunisia     4.0
# 15       Denmark     1.0
# 16         Japan     6.0
# 17         Spain     4.0
# 18       Germany     4.0
# 19    Costa Rica     3.0
# 20       Morocco     7.0
# 21       Croatia     5.0
# 22       Belgium     4.0
# 23        Canada     0.0
# 24        Brazil     6.0
# 25   Switzerland     6.0
# 26      Cameroon     4.0
# 27        Serbia     1.0
# 28      Portugal     6.0
# 29   South Korea     4.0
# 30       Uruguay     4.0
# 31         Ghana     3.0

# %%
#selection of teams that did not lose
df_all[df_all.Loss==0]
# Out:
#     Place in Group         Team  Played  Won  Draw  Loss  Goals For  \
# 0              1.0  Netherlands     3.0  2.0   1.0   0.0        5.0
# 4              1.0      England     3.0  2.0   1.0   0.0        9.0
# 5              2.0          USA     3.0  1.0   2.0   0.0        2.0
# 20             1.0      Morocco     3.0  2.0   1.0   0.0        4.0
# 21             2.0      Croatia     3.0  1.0   2.0   0.0        4.0
#
#     Goals Against  Goal Difference  Points           Form
# 0             1.0              4.0     7.0  W  D  W  W  D
# 4             2.0              7.0     7.0  W  D  W  W  L
# 5             1.0              1.0     5.0     D  D  W  L
# 20            1.0              3.0     7.0  W  D  W  L  L
# 21            1.0              3.0     5.0  D  D  D  L  W

# %%
#selection of teams that received 6 or more points
df_all[df_all.Points>=6]
# Out:
#     Place in Group         Team  Played  Won  Draw  Loss  Goals For  \
# 0              1.0  Netherlands     3.0  2.0   1.0   0.0        5.0
# 1              2.0      Senegal     3.0  2.0   0.0   1.0        5.0
# 4              1.0      England     3.0  2.0   1.0   0.0        9.0
# 8              1.0    Argentina     3.0  2.0   0.0   1.0        5.0
# 12             1.0       France     3.0  2.0   0.0   1.0        6.0
# 13             2.0    Australia     3.0  2.0   0.0   1.0        3.0
# 16             1.0        Japan     3.0  2.0   0.0   1.0        4.0
# 20             1.0      Morocco     3.0  2.0   1.0   0.0        4.0
# 24             1.0       Brazil     3.0  2.0   0.0   1.0        3.0
# 25             2.0  Switzerland     3.0  2.0   0.0   1.0        4.0
# 28             1.0     Portugal     3.0  2.0   0.0   1.0        6.0
#
#     Goals Against  Goal Difference  Points           Form
# 0             1.0              4.0     7.0  W  D  W  W  D
# ...

# %%
#selection of teams that lost and draw
df_all[(df_all.Draw>=1)&(df_all.Loss>=0)]
# Out:
#     Place in Group         Team  Played  Won  Draw  Loss  Goals For  \
# 0              1.0  Netherlands     3.0  2.0   1.0   0.0        5.0
# 2              3.0      Ecuador     3.0  1.0   1.0   1.0        4.0
# 4              1.0      England     3.0  2.0   1.0   0.0        9.0
# 5              2.0          USA     3.0  1.0   2.0   0.0        2.0
# 7              4.0        Wales     3.0  0.0   1.0   2.0        1.0
# 9              2.0       Poland     3.0  1.0   1.0   1.0        2.0
# 10             3.0       Mexico     3.0  1.0   1.0   1.0        2.0
# 14             3.0      Tunisia     3.0  1.0   1.0   1.0        1.0
# 15             4.0      Denmark     3.0  0.0   1.0   2.0        1.0
# 17             2.0        Spain     3.0  1.0   1.0   1.0        9.0
# 18             3.0      Germany     3.0  1.0   1.0   1.0        6.0
# 20             1.0      Morocco     3.0  2.0   1.0   0.0        4.0
# 21             2.0      Croatia     3.0  1.0   2.0   0.0        4.0
# ...

# %%
#creating graphs of each group by points
fig = plt.figure(figsize=(20, 10))
gs = GridSpec(ncols=4, nrows=2, figure=fig)
ax1 = plt.subplot(gs[0, 0])
ax1.plot(df_1group['Team'], df_1group['Form'],color='red',marker='*',linewidth=2)
ax1.set_ylabel('Group A', labelpad = 0, fontsize = 12)
ax1.grid()
ax2 = fig.add_subplot(gs[0, 1])
ax2.plot(df_2group['Team'], df_2group['Form'],marker='*')
ax2.set_ylabel('Group B', labelpad = 0, fontsize = 12)
ax2.grid()
ax3 = fig.add_subplot(gs[0, 2])
ax3.plot(df_3group['Team'], df_3group['Form'],color='red',marker='*')
ax3.set_ylabel('Group C', labelpad = 0, fontsize = 12)
ax3.grid()
ax4 = fig.add_subplot(gs[0, 3])
ax4.plot(df_4group['Team'], df_4group['Form'],marker='*')
ax4.set_ylabel('Group D', labelpad = 0, fontsize = 12)
ax4.grid()
ax5 = plt.subplot(gs[1, 0])
ax5.plot(df_5group['Team'], df_5group['Form'],marker='*')
ax5.set_ylabel('Group E', labelpad = 0, fontsize = 12)
ax5.grid()
ax6 = fig.add_subplot(gs[1, 1])
ax6.plot(df_6group['Team'], df_6group['Form'],color='red',marker='*')
ax6.set_ylabel('Group F', labelpad = 0, fontsize = 12)
ax6.grid()
ax7 = fig.add_subplot(gs[1, 2])
ax7.plot(df_7group['Team'], df_7group['Form'],marker='*')
ax7.set_ylabel('Group G', labelpad = 0, fontsize = 12)
ax7.grid()
ax8 = fig.add_subplot(gs[1, 3])
ax8.plot(df_8group['Team'], df_8group['Form'],color='red',marker='*')
ax8.set_ylabel('Group H', labelpad = 0, fontsize = 12)
ax8.grid()

# %%
#sorting teams by points(descending)
df_all.sort_values(by='Points', ascending=False)
# Out:
#     Place in Group          Team  Played  Won  Draw  Loss  Goals For  \
# 0              1.0   Netherlands     3.0  2.0   1.0   0.0        5.0
# 4              1.0       England     3.0  2.0   1.0   0.0        9.0
# 20             1.0       Morocco     3.0  2.0   1.0   0.0        4.0
# 12             1.0        France     3.0  2.0   0.0   1.0        6.0
# 28             1.0      Portugal     3.0  2.0   0.0   1.0        6.0
# 25             2.0   Switzerland     3.0  2.0   0.0   1.0        4.0
# 24             1.0        Brazil     3.0  2.0   0.0   1.0        3.0
# 1              2.0       Senegal     3.0  2.0   0.0   1.0        5.0
# 13             2.0     Australia     3.0  2.0   0.0   1.0        3.0
# 16             1.0         Japan     3.0  2.0   0.0   1.0        4.0
# 8              1.0     Argentina     3.0  2.0   0.0   1.0        5.0
# 21             2.0       Croatia     3.0  1.0   2.0   0.0        4.0
# 5              2.0           USA     3.0  1.0   2.0   0.0        2.0
# ...
